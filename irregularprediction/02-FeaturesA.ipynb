# %%
# %matplotlib inline
from IPython.display import display, HTML
from analysis import Analysis
from models import *
analysis = Analysis('weather', logger=display)
analysis.load_data()
# Out:
# /anaconda/envs/python35/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# Now setting the predictor to be the avg temperature value.
#
# The features will be the year, month, and day of the current observation.

# %%
predictor = 'actual_mean_temp'
analysis.data['year'] = analysis.data['date'].dt.year
analysis.data['month'] = analysis.data['date'].dt.month
analysis.data['day'] = analysis.data['date'].dt.day
features = ['year', 'month', 'day']
analysis.set_feature_predictor_columns(features, predictor)
analysis.train_test_split()
# Out:
# 'Number of train data points: 292'
# 'Number of test data points: 73'

# %% [markdown]
# Set some parameters that are used by some of the models

# %%
# The number of days to chunk inputs by
NUM_DAYS = 5

# 
NUM_FEATURES = len(analysis.features)

# %% [markdown]
# Going to try each different model.

# %% [markdown]
# ARIMA

# %%
model = ARIMA(analysis)
analysis.run_model(model)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1833.742, BIC=1863.156, Fit time=1.853 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=1968.534, BIC=1994.272, Fit time=0.601 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1869.586, BIC=1895.323, Fit time=1.279 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1835.178, BIC=1868.269, Fit time=2.016 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=1991.156, BIC=2016.893, Fit time=0.743 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.302 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1837.533, BIC=1874.300, Fit time=4.355 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1816.137, BIC=1849.228, Fit time=1.852 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1831.926, BIC=1861.340, Fit time=1.469 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1814.538, BIC=1851.305, Fit time=2.001 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1818.426, BIC=1862.547, Fit time=2.712 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1815.158, BIC=1855.603, Fit time=2.189 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1969.033, BIC=2002.124, Fit time=1.023 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.344 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1817.532, BIC=1861.653, Fit time=5.212 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1812.509, BIC=1845.599, Fit time=1.710 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1814.590, BIC=1851.358, Fit time=2.213 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1816.499, BIC=1856.943, Fit time=2.536 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1813.275, BIC=1850.043, Fit time=2.118 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1976.711, BIC=2006.125, Fit time=0.568 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.317 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1815.594, BIC=1856.038, Fit time=4.997 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1811.581, BIC=1840.995, Fit time=1.657 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1812.481, BIC=1845.572, Fit time=2.079 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1812.779, BIC=1845.870, Fit time=1.929 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1980.652, BIC=2006.389, Fit time=0.376 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.299 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1815.103, BIC=1851.871, Fit time=4.809 seconds
# Total fit time: 53.617 seconds
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-a4aa235188bb> in <module>()
#       1 model = ARIMA(analysis)
# ----> 2 analysis.run_model(model)
#
# /Users/Filip/Projects/irregularprediction/notebooks/analysis.py in run_model(self, model)
#      94         model.train()
#      95
# ---> 96         predicted_train, predicted_test = model.predict()
#      97         self.compute_error(predicted_train, predicted_test)
#      98         self.visualize_data(predicted_train, predicted_test)
#
# /Users/Filip/Projects/irregularprediction/notebooks/models/arima.py in predict(self)
#      34
#      35     def predict(self):
# ---> 36         return self.model.predict_in_sample(), self.model.predict(n_periods=len(self.analysis.y_test))
#
# /anaconda/envs/python35/lib/python3.5/site-packages/pyramid/arima/arima.py in predict_in_sample(self, exogenous, start, end, dynamic)
#     358
#     359         # if we fit with exog, make sure one was passed:
# --> 360         exogenous = self._check_exog(exogenous)  # type: np.ndarray
#     361         return self.arima_res_.predict(exog=exogenous, start=start,
#     362                                        end=end, dynamic=dynamic)
#
# /anaconda/envs/python35/lib/python3.5/site-packages/pyramid/arima/arima.py in _check_exog(self, exogenous)
#     311         if self.fit_with_exog_:
#     312             if exogenous is None:
# --> 313                 raise ValueError('When an ARIMA is fit with an exogenous '
#     314                                  'array, it must be provided one for '
#     315                                  'predicting (either in- OR out-of-sample).')
#
# ValueError: When an ARIMA is fit with an exogenous array, it must be provided one for predicting (either in- OR out-of-sample).

# %%
from sklearn.neighbors import KNeighborsRegressor
model = Regressor(analysis, KNeighborsRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.17465753425  Num NaN: 0'
# 'Test Error: 14.0527777778    Num NaN: 0'

# %%
from sklearn.linear_model import SGDRegressor
model = Regressor(analysis, SGDRegressor)
analysis.run_model(model)
# Out:
# /anaconda/envs/python35/lib/python3.5/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 'Train Error: 3.81287981425e+15  Num NaN: 0'
# 'Test Error: 3.81305720148e+15    Num NaN: 0'

# %%
from sklearn.ensemble import RandomForestRegressor
model = Regressor(analysis, RandomForestRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 1.63630136986  Num NaN: 0'
# 'Test Error: 10.4986111111    Num NaN: 0'

# %%
from sklearn.ensemble import AdaBoostRegressor
model = Regressor(analysis, AdaBoostRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 5.3442677983  Num NaN: 0'
# 'Test Error: 12.9866186142    Num NaN: 0'

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
model = Regressor(analysis, GaussianProcessRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 6.03709906419e-09  Num NaN: 0'
# 'Test Error: 40.8142523091    Num NaN: 0'

# %% [markdown]
# Now going to use models that require chunking.  We perform chunking by taking the time series:
#
# x = (x0, x1, x2, x3, ...)
# y = (x1, x2, x3, x4, ...)
#
# and modifying it such that if the chunk parameter, c, is set to 3:
#
# x = ((x0, x1, x2), (x1, x2, x3), (x2, x3, x4), ...)
# y = (x3, x4, x5, ...)
#
# This results in the first c values in not having a prediction and thus (Num NaN is > 0 and == c).

# %% [markdown]
# LinearRegression

# %%
model = LinearRegression(analysis, num_days=NUM_DAYS)
analysis.run_model(model)
# Out:
# 'Train Error: 9.28226042808  Num NaN: 5'
# 'Test Error: 50.7158892487    Num NaN: 5'

# %% [markdown]
# FeedForward Neural Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

nn = Sequential()
nn.add(layers.Dense(25, activation='tanh',
                    batch_input_shape=(None, NUM_DAYS * NUM_FEATURES)))
nn.add(layers.Dense(10, activation='tanh'))
nn.add(layers.Dense(1, activation='tanh'))
nn.compile(loss='mae', optimizer='sgd')

model = FNN(analysis, nn, num_days=NUM_DAYS)
analysis.run_model(model)
# Out:
# Using TensorFlow backend.
# Train on 287 samples, validate on 67 samples
# Epoch 1/10
#  - 0s - loss: 0.3782 - val_loss: 0.2714
# Epoch 2/10
#  - 0s - loss: 0.2209 - val_loss: 0.2256
# Epoch 3/10
#  - 0s - loss: 0.2212 - val_loss: 0.2567
# Epoch 4/10
#  - 0s - loss: 0.2191 - val_loss: 0.2824
# Epoch 5/10
#  - 0s - loss: 0.2229 - val_loss: 0.2792
# Epoch 6/10
#  - 0s - loss: 0.2212 - val_loss: 0.2096
# Epoch 7/10
#  - 0s - loss: 0.2224 - val_loss: 0.2889
# Epoch 8/10
#  - 0s - loss: 0.2219 - val_loss: 0.2481
# Epoch 9/10
#  - 0s - loss: 0.2217 - val_loss: 0.3033
# Epoch 10/10
#  - 0s - loss: 0.2229 - val_loss: 0.2450
# 'Train Error: 16.4866750099  Num NaN: 5'
# 'Test Error: 18.3767648953    Num NaN: 5'

# %% [markdown]
# Recurrent Neural Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(NUM_DAYS, NUM_FEATURES)))
nn.add(layers.SimpleRNN(50, input_shape=(NUM_DAYS, NUM_FEATURES)))

nn.add(layers.Dense(1, activation='tanh'))
nn.add(layers.Dense(1, activation='linear'))
nn.compile(loss='mae', optimizer=optimizers.RMSprop(lr=0.1))
        
model = RNNSingle(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
analysis.run_model(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c9451ee96d6a> in <module>()
#      14
#      15 model = RNNSingle(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
# ---> 16 analysis.run_model(model)
#
# /Users/Filip/Projects/irregularprediction/notebooks/analysis.py in run_model(self, model)
#      66         model.transform()
#      67         model.build_model()
# ---> 68         model.train()
#      69
#      70         predicted_train, predicted_test = model.predict()
#
# /Users/Filip/Projects/irregularprediction/notebooks/models/rnn_single.py in train(self)
#      19         self.model.fit(self.x_train, self.y_train, epochs=10, validation_data=(self.x_test, self.y_test),
#      20                        batch_size=10,
# ---> 21                        verbose=2)
#      22
#      23     def predict(self):
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     891                               class_weight=class_weight,
#     892                               sample_weight=sample_weight,
# --> 893                               initial_epoch=initial_epoch)
#     894
#     895     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1553             class_weight=class_weight,
#    1554             check_batch_axis=False,
# -> 1555             batch_size=batch_size)
#    1556         # Prepare validation data.
#    1557         do_validation = False
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1407                                     self._feed_input_shapes,
#    1408                                     check_batch_axis=False,
# -> 1409                                     exception_prefix='input')
#    1410         y = _standardize_input_data(y, self._feed_output_names,
#    1411                                     output_shapes,
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     140                                  ' to have ' + str(len(shapes[i])) +
#     141                                  ' dimensions, but got array with shape ' +
# --> 142                                  str(array.shape))
#     143             for j, (dim, ref_dim) in enumerate(zip(array.shape, shapes[i])):
#     144                 if not j and not check_batch_axis:
#
# ValueError: Error when checking input: expected masking_3_input to have 3 dimensions, but got array with shape (287, 5)

# %% [markdown]
# LSTM Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(NUM_DAYS, NUM_FEATURES)))
nn.add(layers.LSTM(50, activation='tanh', input_shape=(NUM_DAYS, NUM_FEATURES), return_sequences=True))

nn.add(layers.TimeDistributed(layers.Dense(10, activation='relu')))
nn.add(layers.TimeDistributed(layers.Dense(1, activation='tanh')))
# nn.add(layers.TimeDistributed(layers.Dense(1, activation='linear')))
nn.compile(loss='mae', optimizer='rmsprop')

model = RNNMultiple(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
analysis.run_model(model)

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(len(analysis.x_train), NUM_FEATURES)))
nn.add(layers.LSTM(50, activation='tanh', input_shape=(len(analysis.x_train), NUM_FEATURES), return_sequences=True))

nn.add(layers.TimeDistributed(layers.Dense(10, activation='relu')))
nn.add(layers.TimeDistributed(layers.Dense(1, activation='tanh')))
# nn.add(layers.TimeDistributed(layers.Dense(1, activation='linear')))
nn.compile(loss='mae', optimizer='rmsprop')

model = RNNAll(analysis, nn, mask_value=mask_value)
analysis.run_model(model)
