# %%
# %matplotlib inline
from IPython.display import display, HTML
from analysis import Analysis
from models import *
analysis = Analysis('weather', logger=display)
analysis.load_data()
# Out:
# /anaconda/envs/python35/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# Now setting the features and predictor to just be the avg temperature value.

# %%
predictor = 'actual_mean_temp'
features = [predictor]
analysis.set_feature_predictor_columns(features, predictor)
analysis.train_test_split()
# Out:
# 'Number of train data points: 292'
# 'Number of test data points: 73'

# %% [markdown]
# Set some parameters that are used by some of the models

# %%
# The number of days to chunk inputs by
NUM_DAYS = 5

# 
NUM_FEATURES = len(analysis.features)

# %% [markdown]
# Going to try each different model.

# %% [markdown]
# ARIMA

# %%
model = ARIMA(analysis, use_features=False)
analysis.run_model(model)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1827.791, BIC=1846.175, Fit time=1.289 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=1962.638, BIC=1977.345, Fit time=0.323 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1864.170, BIC=1878.877, Fit time=0.656 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1829.085, BIC=1851.146, Fit time=1.280 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=1986.101, BIC=2000.808, Fit time=0.374 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.263 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1831.275, BIC=1857.012, Fit time=5.152 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1811.604, BIC=1833.664, Fit time=1.389 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1828.408, BIC=1846.792, Fit time=0.824 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1809.098, BIC=1834.836, Fit time=1.562 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1813.071, BIC=1846.162, Fit time=1.881 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1809.645, BIC=1839.059, Fit time=1.697 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1964.821, BIC=1986.881, Fit time=0.662 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.318 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1812.163, BIC=1845.254, Fit time=4.824 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1807.133, BIC=1829.193, Fit time=1.133 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1809.111, BIC=1834.848, Fit time=1.646 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1811.125, BIC=1840.539, Fit time=1.638 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1807.772, BIC=1833.509, Fit time=1.619 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1973.603, BIC=1991.987, Fit time=0.270 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.264 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1809.991, BIC=1839.405, Fit time=3.806 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1806.821, BIC=1825.205, Fit time=1.100 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1807.112, BIC=1829.173, Fit time=1.357 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1807.454, BIC=1829.515, Fit time=1.499 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1980.201, BIC=1994.908, Fit time=0.258 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=0.269 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1809.529, BIC=1835.266, Fit time=4.104 seconds
# Total fit time: 41.464 seconds
# 'Train Error: 5.07415076317  Num NaN: 0'
# 'Test Error: 6.39170757717    Num NaN: 0'

# %%
from sklearn.neighbors import KNeighborsRegressor
model = Regressor(analysis, KNeighborsRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.50479452055  Num NaN: 0'
# 'Test Error: 4.60555555556    Num NaN: 0'

# %%
from sklearn.linear_model import SGDRegressor
model = Regressor(analysis, SGDRegressor)
analysis.run_model(model)
# Out:
# /anaconda/envs/python35/lib/python3.5/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 'Train Error: 3.42625642663e+12  Num NaN: 0'
# 'Test Error: 4.57455056696e+12    Num NaN: 0'

# %%
from sklearn.ensemble import RandomForestRegressor
model = Regressor(analysis, RandomForestRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.32831114852  Num NaN: 0'
# 'Test Error: 4.39164799321    Num NaN: 0'

# %%
from sklearn.ensemble import AdaBoostRegressor
model = Regressor(analysis, AdaBoostRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.62688104462  Num NaN: 0'
# 'Test Error: 4.67451952097    Num NaN: 0'

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
model = Regressor(analysis, GaussianProcessRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.26186708473  Num NaN: 0'
# 'Test Error: 4.49174209436    Num NaN: 0'

# %% [markdown]
# Now going to use models that require chunking.  We perform chunking by taking the time series:
#
# x = (x0, x1, x2, x3, ...)
# y = (x1, x2, x3, x4, ...)
#
# and modifying it such that if the chunk parameter, c, is set to 3:
#
# x = ((x0, x1, x2), (x1, x2, x3), (x2, x3, x4), ...)
# y = (x3, x4, x5, ...)
#
# This results in the first c values in not having a prediction and thus (Num NaN is > 0 and == c).

# %% [markdown]
# LinearRegression

# %%
model = LinearRegression(analysis, num_days=NUM_DAYS)
analysis.run_model(model)
# Out:
# 'Train Error: 5.70952644694  Num NaN: 5'
# 'Test Error: 6.19872245938    Num NaN: 5'

# %% [markdown]
# FeedForward Neural Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

nn = Sequential()
nn.add(layers.Dense(25, activation='tanh',
                    batch_input_shape=(None, NUM_DAYS * NUM_FEATURES)))
nn.add(layers.Dense(10, activation='tanh'))
nn.add(layers.Dense(1, activation='tanh'))
nn.compile(loss='mae', optimizer='sgd')

model = FNN(analysis, nn, num_days=NUM_DAYS)
analysis.run_model(model)
# Out:
# Using TensorFlow backend.
# Train on 287 samples, validate on 67 samples
# Epoch 1/10
#  - 0s - loss: 0.2072 - val_loss: 0.1286
# Epoch 2/10
#  - 0s - loss: 0.2091 - val_loss: 0.1656
# Epoch 3/10
#  - 0s - loss: 0.1928 - val_loss: 0.1827
# Epoch 4/10
#  - 0s - loss: 0.1875 - val_loss: 0.1394
# Epoch 5/10
#  - 0s - loss: 0.1882 - val_loss: 0.1328
# Epoch 6/10
#  - 0s - loss: 0.1897 - val_loss: 0.1927
# Epoch 7/10
#  - 0s - loss: 0.1892 - val_loss: 0.2781
# Epoch 8/10
#  - 0s - loss: 0.1777 - val_loss: 0.1250
# Epoch 9/10
#  - 0s - loss: 0.1892 - val_loss: 0.1173
# Epoch 10/10
#  - 0s - loss: 0.1884 - val_loss: 0.1336
# 'Train Error: 13.6464903828  Num NaN: 5'
# 'Test Error: 10.0201768448    Num NaN: 5'

# %% [markdown]
# Recurrent Neural Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(NUM_DAYS, NUM_FEATURES)))
nn.add(layers.SimpleRNN(50, input_shape=(NUM_DAYS, NUM_FEATURES)))

nn.add(layers.Dense(1, activation='tanh'))
nn.add(layers.Dense(1, activation='linear'))
nn.compile(loss='mae', optimizer=optimizers.RMSprop(lr=0.1))
        
model = RNNSingle(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
analysis.run_model(model)
# Out:
# Train on 287 samples, validate on 67 samples
# Epoch 1/10
#  - 0s - loss: 0.2941 - val_loss: 0.2068
# Epoch 2/10
#  - 0s - loss: 0.2412 - val_loss: 0.3879
# Epoch 3/10
#  - 0s - loss: 0.2497 - val_loss: 0.2243
# Epoch 4/10
#  - 0s - loss: 0.2411 - val_loss: 0.1021
# Epoch 5/10
#  - 0s - loss: 0.2278 - val_loss: 0.3994
# Epoch 6/10
#  - 0s - loss: 0.2395 - val_loss: 0.2537
# Epoch 7/10
#  - 0s - loss: 0.2490 - val_loss: 0.4313
# Epoch 8/10
#  - 0s - loss: 0.2430 - val_loss: 0.4623
# Epoch 9/10
#  - 0s - loss: 0.2329 - val_loss: 0.0949
# Epoch 10/10
#  - 0s - loss: 0.2339 - val_loss: 0.2672
# 'Train Error: 16.4457534498  Num NaN: 5'
# 'Test Error: 20.042136292    Num NaN: 5'

# %% [markdown]
# LSTM Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(NUM_DAYS, NUM_FEATURES)))
nn.add(layers.LSTM(50, activation='tanh', input_shape=(NUM_DAYS, NUM_FEATURES), return_sequences=True))

nn.add(layers.TimeDistributed(layers.Dense(10, activation='relu')))
nn.add(layers.TimeDistributed(layers.Dense(1, activation='tanh')))
# nn.add(layers.TimeDistributed(layers.Dense(1, activation='linear')))
nn.compile(loss='mae', optimizer='rmsprop')

model = RNNMultiple(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
analysis.run_model(model)
# Out:
# Train on 59 samples, validate on 15 samples
# Epoch 1/10
#  - 1s - loss: 0.4636 - val_loss: 0.3490
# Epoch 2/10
#  - 0s - loss: 0.2316 - val_loss: 0.1952
# Epoch 3/10
#  - 0s - loss: 0.1222 - val_loss: 0.1130
# Epoch 4/10
#  - 0s - loss: 0.0686 - val_loss: 0.0672
# Epoch 5/10
#  - 0s - loss: 0.0403 - val_loss: 0.0408
# Epoch 6/10
#  - 0s - loss: 0.0240 - val_loss: 0.0246
# Epoch 7/10
#  - 0s - loss: 0.0147 - val_loss: 0.0152
# Epoch 8/10
#  - 0s - loss: 0.0097 - val_loss: 0.0097
# Epoch 9/10
#  - 0s - loss: 0.0069 - val_loss: 0.0065
# Epoch 10/10
#  - 0s - loss: 0.0054 - val_loss: 0.0047
# 'Train Error: 47.9564521476  Num NaN: 0'
# 'Test Error: 46.4681090779    Num NaN: 0'

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(len(analysis.x_train), NUM_FEATURES)))
nn.add(layers.LSTM(50, activation='tanh', input_shape=(len(analysis.x_train), NUM_FEATURES), return_sequences=True))

nn.add(layers.TimeDistributed(layers.Dense(10, activation='relu')))
nn.add(layers.TimeDistributed(layers.Dense(1, activation='tanh')))
# nn.add(layers.TimeDistributed(layers.Dense(1, activation='linear')))
nn.compile(loss='mae', optimizer='rmsprop')

model = RNNAll(analysis, nn, mask_value=mask_value)
analysis.run_model(model)
# Out:
# /anaconda/envs/python35/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Train on 1 samples, validate on 1 samples
# Epoch 1/10
#  - 1s - loss: 1.5173 - val_loss: 1.4072
# Epoch 2/10
#  - 1s - loss: 1.3090 - val_loss: 1.1788
# Epoch 3/10
#  - 1s - loss: 1.1372 - val_loss: 1.0035
# Epoch 4/10
#  - 1s - loss: 0.9592 - val_loss: 0.8538
# Epoch 5/10
#  - 1s - loss: 0.8235 - val_loss: 0.7521
# Epoch 6/10
#  - 1s - loss: 0.7092 - val_loss: 0.6632
# Epoch 7/10
#  - 1s - loss: 0.6011 - val_loss: 0.5704
# Epoch 8/10
#  - 1s - loss: 0.4935 - val_loss: 0.4730
# Epoch 9/10
#  - 1s - loss: 0.4198 - val_loss: 0.3934
# Epoch 10/10
#  - 1s - loss: 0.3421 - val_loss: 0.2501
# 'Train Error: 2326.94675937  Num NaN: 0'
# 'Test Error: 2522.57019721    Num NaN: 0'
