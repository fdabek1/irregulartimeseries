# %%
# %matplotlib inline
from IPython.display import display, HTML
from analysis import Analysis
from models import *
analysis = Analysis('weather', normalize=True, logger=display)
analysis.load_data()
# Out:
# D:\Users\fjd10\Anaconda3\envs\tensorflow\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# Now setting the predictor to be the avg temperature value.
#
# The features will be the actual_min_temp, actual_max_temp, and the actual_precipitation and the predictor value.

# %%
predictor = 'actual_mean_temp'
features = ['actual_min_temp', 'actual_max_temp', 'actual_precipitation', predictor]
analysis.set_feature_predictor_columns(features, predictor)
analysis.train_test_split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2fab7f73d5da> in <module>()
#       1 predictor = 'actual_mean_temp'
#       2 features = ['actual_min_temp', 'actual_max_temp', 'actual_precipitation', predictor]
# ----> 3 analysis.set_feature_predictor_columns(features, predictor)
#       4 analysis.train_test_split()
#
# NameError: name 'analysis' is not defined

# %% [markdown]
# Set some parameters that are used by some of the models

# %%
# The number of days to chunk inputs by
NUM_DAYS = 5

# 
NUM_FEATURES = len(analysis.features)

# %% [markdown]
# Going to try each different model.

# %% [markdown]
# ARIMA

# %%
model = ARIMA(analysis)
analysis.run_model(model)
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1827.791, BIC=1846.175, Fit time=1.913 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 12); AIC=1962.638, BIC=1977.345, Fit time=0.504 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1864.170, BIC=1878.877, Fit time=1.068 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 12); AIC=1829.085, BIC=1851.146, Fit time=2.071 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 12); AIC=1986.101, BIC=2000.808, Fit time=0.662 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 12); AIC=1831.230, BIC=1856.967, Fit time=6.357 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 12); AIC=1811.604, BIC=1833.664, Fit time=2.240 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 1, 1, 12); AIC=1828.408, BIC=1846.792, Fit time=1.150 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1809.098, BIC=1834.836, Fit time=2.474 seconds
# Fit ARIMA: order=(3, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1813.071, BIC=1846.162, Fit time=3.256 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1809.645, BIC=1839.059, Fit time=2.695 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1964.821, BIC=1986.882, Fit time=0.898 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1812.164, BIC=1845.255, Fit time=8.341 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1807.133, BIC=1829.193, Fit time=1.771 seconds
# Fit ARIMA: order=(1, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1809.107, BIC=1834.845, Fit time=2.791 seconds
# Fit ARIMA: order=(2, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1811.125, BIC=1840.539, Fit time=2.508 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1807.772, BIC=1833.509, Fit time=2.566 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1973.603, BIC=1991.987, Fit time=0.418 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1809.938, BIC=1839.352, Fit time=6.237 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 1, 12); AIC=1806.821, BIC=1825.205, Fit time=1.512 seconds
# Fit ARIMA: order=(0, 1, 3) seasonal_order=(0, 1, 1, 12); AIC=1807.112, BIC=1829.173, Fit time=2.421 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 1, 12); AIC=1807.454, BIC=1829.515, Fit time=2.211 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 0, 12); AIC=1980.201, BIC=1994.908, Fit time=0.356 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(0, 1, 2, 12); AIC=nan, BIC=nan, Fit time=1.851 seconds
# Fit ARIMA: order=(0, 1, 2) seasonal_order=(1, 1, 2, 12); AIC=1809.532, BIC=1835.269, Fit time=5.355 seconds
# Total fit time: 64.001 seconds
# 292 292
# 'Train Error: 5.07417608657\tNum NaN: 0'
# 'Test Error: 6.38998095112\tNum NaN: 0'

# %%
from sklearn.neighbors import KNeighborsRegressor
model = Regressor(analysis, KNeighborsRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.50479452055  Num NaN: 0'
# 'Test Error: 4.60555555556    Num NaN: 0'
# 'showing raw'

# %%
from sklearn.linear_model import SGDRegressor
model = Regressor(analysis, SGDRegressor)
analysis.run_model(model)
# Out:
# D:\Users\fjd10\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 'Train Error: 3.89040092936e+12  Num NaN: 0'
# 'Test Error: 5.2007977972e+12    Num NaN: 0'
# 'showing raw'

# %%
from sklearn.ensemble import RandomForestRegressor
model = Regressor(analysis, RandomForestRegressor)
analysis.run_model(model)
# Out:
# 292 292
# 'Train Error: 4.34717283002\tNum NaN: 0'
# 'Test Error: 4.4297505311\tNum NaN: 0'

# %%
from sklearn.ensemble import AdaBoostRegressor
model = Regressor(analysis, AdaBoostRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.71050897108\tNum NaN: 0'
# 'Test Error: 4.71205352752\tNum NaN: 0'

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
model = Regressor(analysis, GaussianProcessRegressor)
analysis.run_model(model)
# Out:
# 'Train Error: 4.26186708473\tNum NaN: 0'
# 'Test Error: 4.49174209436\tNum NaN: 0'

# %% [markdown]
# Now going to use models that require chunking.  We perform chunking by taking the time series:
#
# x = (x0, x1, x2, x3, ...)
# y = (x1, x2, x3, x4, ...)
#
# and modifying it such that if the chunk parameter, c, is set to 3:
#
# x = ((x0, x1, x2), (x1, x2, x3), (x2, x3, x4), ...)
# y = (x3, x4, x5, ...)
#
# This results in the first c values in not having a prediction and thus (Num NaN is > 0 and == c).

# %% [markdown]
# LinearRegression

# %%
model = LinearRegression(analysis, num_days=NUM_DAYS)
analysis.run_model(model)
# Out:
# 'Train Error: 5.70952644694\tNum NaN: 5'
# 'Test Error: 6.19872245938\tNum NaN: 5'

# %% [markdown]
# FeedForward Neural Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

nn = Sequential()
nn.add(layers.Dense(25, activation='tanh',
                    batch_input_shape=(None, NUM_DAYS * NUM_FEATURES)))
nn.add(layers.Dense(10, activation='tanh'))
nn.add(layers.Dense(1, activation='tanh'))
nn.compile(loss='mae', optimizer='sgd')

model = FNN(analysis, nn, num_days=NUM_DAYS)
analysis.run_model(model)
# Out:
# Using TensorFlow backend.
# Train on 287 samples, validate on 67 samples
# Epoch 1/10
#  - 0s - loss: 53.0472 - val_loss: 72.1792
# Epoch 2/10
#  - 0s - loss: 52.4672 - val_loss: 71.5992
# Epoch 3/10
#  - 0s - loss: 51.8872 - val_loss: 71.0192
# Epoch 4/10
#  - 0s - loss: 51.3072 - val_loss: 70.4392
# Epoch 5/10
#  - 0s - loss: 50.7272 - val_loss: 69.8592
# Epoch 6/10
#  - 0s - loss: 50.1472 - val_loss: 69.2792
# Epoch 7/10
#  - 0s - loss: 49.5672 - val_loss: 68.6992
# Epoch 8/10
#  - 0s - loss: 48.9872 - val_loss: 68.1192
# Epoch 9/10
#  - 0s - loss: 48.4072 - val_loss: 67.5392
# Epoch 10/10
#  - 0s - loss: 47.8272 - val_loss: 66.9592
# 'Train Error: 47.5243178411\tNum NaN: 5'
# 'Test Error: 66.9592338534\tNum NaN: 5'

# %% [markdown]
# Recurrent Neural Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(NUM_DAYS, NUM_FEATURES)))
nn.add(layers.SimpleRNN(50, input_shape=(NUM_DAYS, NUM_FEATURES)))

nn.add(layers.Dense(1, activation='tanh'))
nn.add(layers.Dense(1, activation='linear'))
nn.compile(loss='mae', optimizer=optimizers.RMSprop(lr=0.1))
        
model = RNNSingle(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
analysis.run_model(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c9451ee96d6a> in <module>()
#      14
#      15 model = RNNSingle(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
# ---> 16 analysis.run_model(model)
#
# /Users/Filip/Projects/irregularprediction/notebooks/analysis.py in run_model(self, model)
#      66         model.transform()
#      67         model.build_model()
# ---> 68         model.train()
#      69
#      70         predicted_train, predicted_test = model.predict()
#
# /Users/Filip/Projects/irregularprediction/notebooks/models/rnn_single.py in train(self)
#      19         self.model.fit(self.x_train, self.y_train, epochs=10, validation_data=(self.x_test, self.y_test),
#      20                        batch_size=10,
# ---> 21                        verbose=2)
#      22
#      23     def predict(self):
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     891                               class_weight=class_weight,
#     892                               sample_weight=sample_weight,
# --> 893                               initial_epoch=initial_epoch)
#     894
#     895     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1553             class_weight=class_weight,
#    1554             check_batch_axis=False,
# -> 1555             batch_size=batch_size)
#    1556         # Prepare validation data.
#    1557         do_validation = False
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1407                                     self._feed_input_shapes,
#    1408                                     check_batch_axis=False,
# -> 1409                                     exception_prefix='input')
#    1410         y = _standardize_input_data(y, self._feed_output_names,
#    1411                                     output_shapes,
#
# /anaconda/envs/python35/lib/python3.5/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     140                                  ' to have ' + str(len(shapes[i])) +
#     141                                  ' dimensions, but got array with shape ' +
# --> 142                                  str(array.shape))
#     143             for j, (dim, ref_dim) in enumerate(zip(array.shape, shapes[i])):
#     144                 if not j and not check_batch_axis:
#
# ValueError: Error when checking input: expected masking_3_input to have 3 dimensions, but got array with shape (287, 5)

# %% [markdown]
# LSTM Network

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(NUM_DAYS, NUM_FEATURES)))
nn.add(layers.LSTM(50, activation='tanh', input_shape=(NUM_DAYS, NUM_FEATURES), return_sequences=True))

nn.add(layers.TimeDistributed(layers.Dense(10, activation='relu')))
nn.add(layers.TimeDistributed(layers.Dense(1, activation='tanh')))
# nn.add(layers.TimeDistributed(layers.Dense(1, activation='linear')))
nn.compile(loss='mae', optimizer='rmsprop')

model = RNNMultiple(analysis, nn, num_days=NUM_DAYS, mask_value=mask_value)
analysis.run_model(model)

# %%
from keras.models import Sequential
from keras import optimizers
from keras import layers

mask_value = -9999

nn = Sequential()
nn.add(layers.Masking(mask_value=mask_value, input_shape=(len(analysis.x_train), NUM_FEATURES)))
nn.add(layers.LSTM(50, activation='tanh', input_shape=(len(analysis.x_train), NUM_FEATURES), return_sequences=True))

nn.add(layers.TimeDistributed(layers.Dense(10, activation='relu')))
nn.add(layers.TimeDistributed(layers.Dense(1, activation='tanh')))
# nn.add(layers.TimeDistributed(layers.Dense(1, activation='linear')))
nn.compile(loss='mae', optimizer='rmsprop')

model = RNNAll(analysis, nn, mask_value=mask_value)
analysis.run_model(model)
